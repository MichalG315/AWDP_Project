# %%
# Export to HTML
# !jupyter nbconvert --execute --to html main.ipynb --template classic --output-dir=output
# Out:
# [NbConvertApp] Making directory output
# [NbConvertApp] Converting notebook main.ipynb to html
# [IPKernelApp] WARNING | Kernel is running over TCP without encryption. All communication (including code and outputs) is sent in plain text and is susceptible to eavesdropping. Use IPC transport or launch with kernel manager-provisioned CurveZMQ keys to enable transport encryption.
# [NbConvertApp] WARNING | Alternative text is missing on 9 image(s).
# [NbConvertApp] Writing 1132858 bytes to output/main.html

# %%
# Export to PDF, pandoc and Latex is required for this
# !jupyter nbconvert --execute --to pdf main.ipynb --output-dir=output
# Out:
# [NbConvertApp] Converting notebook main.ipynb to pdf
# [IPKernelApp] WARNING | Kernel is running over TCP without encryption. All communication (including code and outputs) is sent in plain text and is susceptible to eavesdropping. Use IPC transport or launch with kernel manager-provisioned CurveZMQ keys to enable transport encryption.
# [NbConvertApp] Support files will be in main_files/
# [NbConvertApp] Making directory ./main_files
# [NbConvertApp] Writing 82150 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 621305 bytes to output/main.pdf
